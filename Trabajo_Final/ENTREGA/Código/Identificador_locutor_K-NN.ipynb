# %% [markdown]
# Grupo 2 - Identificacion del locutor K-Nearest Neighbor.
# Elena Maria del Rio Galera,
# Yolanda Lillo Mata,
# Cristina Taboada Mayo

# %% [markdown]
# Lectura de Datos

# %%
"""CARGAR DATOS"""
#imports
# %matplotlib notebook
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
import scipy.io.wavfile as wf

#Cogemos archivos de audio de los locutores
loc1 = 'Dame_pan_dime_tonto1canal.wav'
loc2 = 'elmo1canal.wav'
loc3 = 'Tal_palo_tal_astilla1canal.wav'
loc4 = 'Perro_ladrador_poco_mordedor1canal.wav'

#Extraemos los datos de la señal y los visualizamos en pantalla

fs1,y1 = wf.read(loc1)
y1 = y1[:,0]
print(fs1)
print(y1)

fs2,y2 = wf.read(loc2)
print(fs2)
print(y2)

fs3,y3 = wf.read(loc3)
y3 = y3[:,0]
print(fs3)
print(y3)

fs4,y4 = wf.read(loc4)
y4 = y4[:,0]
print(fs4)
print(y4)

#Dibujamos las gráficas y sacamos su tiempo para cada locutor

#Vector de tiempo locutor 1
t1 = np.arange(0,len(y1))/fs1

plt.figure(figsize = (7,5))

#Obtenemos figura 1

plt.plot(t1,y1)
plt.title('Locutor 1')
plt.xlabel('Tiempo [seg]')
plt.ylabel('Amplitud')

#Vector de tiempo locutor 2
t2= np.arange(0,len(y2))/fs2
print(t2)
plt.figure(figsize = (7,5))

#Obtenemos figura 2

plt.plot(t2,y2)
plt.title('Locutor 2')
plt.xlabel('Tiempo [seg]')
plt.ylabel('Amplitud')

#Vector de tiempo locutor 3
t3 = np.arange(0,len(y3))/fs3

plt.figure(figsize = (7,5))

#Obtenemos figura 3

plt.plot(t3,y3)
plt.title('Locutor 3')
plt.xlabel('Tiempo [seg]')
plt.ylabel('Amplitud')

#Vector de tiempo locutor 3
t4 = np.arange(0,len(y4))/fs4
plt.figure(figsize = (7,5))

#Obtenemos figura 4

plt.plot(t4,y4)
plt.title('Locutor 4')
plt.xlabel('Tiempo [seg]')
plt.ylabel('Amplitud')
# Out:
# 48000
# [  0   0   0 ... -14  -9  -9]
# 48000
# [ 1 -3  4 ... 10  9 20]
# 48000
# [ -9 -11 -12 ... -54 -61 -56]
# 48000
# [  0   0   1 ... -33 -34 -37]
# /home/alumno/.conda/envs/tds_20_21/lib/python3.6/site-packages/ipykernel_launcher.py:17: WavFileWarning: Chunk (non-data) not understood, skipping it.
# /home/alumno/.conda/envs/tds_20_21/lib/python3.6/site-packages/ipykernel_launcher.py:26: WavFileWarning: Chunk (non-data) not understood, skipping it.
# /home/alumno/.conda/envs/tds_20_21/lib/python3.6/site-packages/ipykernel_launcher.py:31: WavFileWarning: Chunk (non-data) not understood, skipping it.
# <img src="data:image/png;base64,..." width="699.999984827909">
# [0.00000000e+00 2.08333333e-05 4.16666667e-05 ... 6.01787500e+00
#  6.01789583e+00 6.01791667e+00]
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# ...

# %% [markdown]
# Representacion de las señales

# %%
#Representamos las muestras de cada locutor
# Muestra figura 1
plt.figure(figsize = (7,5))
plt.plot(y1)
plt.title('Muestras locutor 1')
plt.xlabel("Muestras")
plt.ylabel('Amplitud')

# Muestra figura 2
plt.figure(figsize = (7,5))
plt.plot(y2)
plt.title('Muestras locutor 2')
plt.xlabel("Muestras")
plt.ylabel('Amplitud')

# Muestra figura 3
plt.figure(figsize = (7,5))
plt.plot(y3)
plt.title('Muestras locutor 3')
plt.xlabel("Muestras")
plt.ylabel('Amplitud')

# Muestra figura 4
plt.figure(figsize = (7,5))
plt.plot(y4)
plt.title('Muestras locutor 4')
plt.xlabel("Muestras")
plt.ylabel('Amplitud')
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# Representacion del espectro de la primera palabra de cada locutor

# %%
from tds_utils import my_spectra
import scipy.signal as sig

# Locutor 1 - fs=48000 -> para una ventana de 20ms tenemos que coger 9600 muestras.
s1 = y1[18000:27600]
psd1,f1 = my_spectra(s1,fs1)
print(f1)
# Elegimos las frecuencias positivas
idx = f1 >= 0
plt.figure(figsize=(7,5))
plt.plot(f1[idx], psd1[idx])

plt.title('Locutor 1')
plt.ylabel('Psd')
plt.xlabel('Frecuencia [Hz]')

# Locutor 2 - fs=48000 -> para una ventana de 20ms tenemos que coger 9600 muestras.
s2 = y2[35000:44600]
psd2,f2 = my_spectra(s2,fs2)
print(f2)
# Elegimos las frecuencias positivas
idx = f2 >= 0
plt.figure(figsize=(7,5))
plt.plot(f2[idx], psd2[idx])

plt.title('Locutor 2')
plt.ylabel('Psd')
plt.xlabel('Frecuencia [Hz]')

# Locutor 3 - fs=48000 -> para una ventana de 20ms tenemos que coger 9600 muestras.
s3 = y3[15000:24600]
psd3,f3 = my_spectra(s3,fs3)
print(f3)
# Elegimos las frecuencias positivas
idx = f3 >= 0
plt.figure(figsize=(7,5))
plt.plot(f3[idx], psd3[idx])

plt.title('Locutor 3')
plt.ylabel('Psd')
plt.xlabel('Frecuencia [Hz]')

# Locutor 4 - fs=48000 -> para una ventana de 20ms tenemos que coger 9600 muestras.
s4 = y4[80000:89600]
psd4,f4 = my_spectra(s4,fs4)
print(f4)
# Elegimos las frecuencias positivas
idx = f4 >= 0
plt.figure(figsize=(7,5))
plt.plot(f4[idx], psd4[idx])

plt.title('Locutor 4')
plt.ylabel('Psd')
plt.xlabel('Frecuencia [Hz]')
# Out:
# [-24000.         -23998.53515625 -23997.0703125  ...  23995.60546875
#   23997.0703125   23998.53515625]
# <img src="data:image/png;base64,..." width="699.999984827909">
# [-24000.         -23998.53515625 -23997.0703125  ...  23995.60546875
#   23997.0703125   23998.53515625]
# <img src="data:image/png;base64,..." width="699.999984827909">
# [-24000.         -23998.53515625 -23997.0703125  ...  23995.60546875
#   23997.0703125   23998.53515625]
# <img src="data:image/png;base64,..." width="699.999984827909">
# [-24000.         -23998.53515625 -23997.0703125  ...  23995.60546875
#   23997.0703125   23998.53515625]
# <img src="data:image/png;base64,..." width="699.999984827909">
# Text(0.5, 0, 'Frecuencia [Hz]')

# %% [markdown]
# Extraccion de caracteristicas de cada locutor

# %%
from scipy.signal import find_peaks

# Creamos una lista para guardar los valores del pitch de los distintos locutores
pitch_list = []

# %%
# Sacamos los picos del locutor 1
x1 = psd1[idx]
peaks, _ = find_peaks(x1, height=200)
# peaks es el array de las posiciones en el eje x donde se encuentran 
# los picos por encima de 200.
plt.figure()
plt.plot(x1)
plt.plot(peaks, x1[peaks], "x")
plt.show()

# Obtenemos el pitch del locutor 1
x11 = peaks[0]
x12 = x1[peaks[0]]
print(x11, x12)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 111 201.23033443657687

# %%
# Sacamos los picos del locutor 2
x2 = psd2[idx]
peaks, _ = find_peaks(x2, height=200)
plt.figure()
plt.plot(x2)
plt.plot(peaks, x2[peaks], "x")
plt.show()

# Obtenemos el pitch del locutor 2
x21 = peaks[0]
x22 = x2[peaks[0]]
print(x21, x22)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 248 242.51883702340984

# %%
# Sacamos los picos del locutor 3
x3 = psd3[idx]
peaks, _ = find_peaks(x3, height=200)
plt.figure()
plt.plot(x3)
plt.plot(peaks, x3[peaks], "x")
plt.show()

# Obtenemos el pitch del locutor 3
x31 = peaks[0]
x32 = x3[peaks[0]]
print(x31, x32)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 120 242.37056304356187

# %%
# Sacamos los picos del locutor 4
x4 = psd4[idx]
peaks, _ = find_peaks(x4, height=200)
plt.figure()
plt.plot(x4)
plt.plot(peaks, x4[peaks], "x")
plt.show()

# Obtenemos el pitch del locutor 4
x41 = peaks[0]
x42 = x4[peaks[0]]
print(x41, x42)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 98 340.75063446067463

# %%
from sklearn.model_selection import train_test_split

# Creamos la matriz de entrenamiento xtrain con los valores del pitch
xtrain = [[x11, x12],
          [x21, x22],
          [x31, x32],
          [x41, x42]
         ]

# Creamos la matriz de la clase asociada a cada conjunto de datos, ytrain
ytrain = [['loc1'],
          ['loc2'],
          ['loc3'],
          ['loc4']
         ]

# Visualizamos los datos de entrenamiento
print('------TRAIN--------')
print(xtrain)
print(ytrain)
print('-------------------')

# Creamos la matriz de test a partir de los datos de las matrices de entrenamiento.
# Se utilizan el 30% de los datos de las matrices de entrenamiento para crear la
# matriz de test.
x, xtest, y, ytest = train_test_split(xtrain, ytrain, test_size=0.3)

# Visualizamos los datos de test
print('------TEST-------')
print(xtest)
print(ytest)
print('-----------------')
# Out:
# ------TRAIN--------
# [[111, 201.23033443657687], [248, 242.51883702340984], [120, 242.37056304356187], [98, 340.75063446067463]]
# [['loc1'], ['loc2'], ['loc3'], ['loc4']]
# -------------------
# ------TEST-------
# [[248, 242.51883702340984], [120, 242.37056304356187]]
# [['loc2'], ['loc3']]
# -----------------

# %% [markdown]
# Cargar datos para la aplicacion del algoritmo K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier
import sys

# Creamos varios clasificadores para ver con cuantos n vecinos mas proximos es mas preciso

# Creamos el clasificador para n=1 
KNN_classifier = KNeighborsClassifier(n_neighbors=1)

# Entrenamiento
KNN_classifier.fit(xtrain, ytrain)

# Prediccion
y_hat_KNN = KNN_classifier.predict(xtest)
print(y_hat_KNN)

# Precision
acc = np.sum (ytest == y_hat_KNN)/len(ytest)
print('El algoritmo con n=1 tiene una precision del: ' + str(acc))


# Creamos el clasificador para n=2
KNN_classifier = KNeighborsClassifier(n_neighbors=2)

# Entrenamiento
KNN_classifier.fit(xtrain, ytrain)

# Prediccion
y_hat_KNN = KNN_classifier.predict(xtest)
print(y_hat_KNN)

# Precision
acc = np.sum (ytest == y_hat_KNN)/len(ytest)
print('El algoritmo con n=2 tiene una precision del: ' + str(acc))


# Creamos el clasificador para n=3
KNN_classifier = KNeighborsClassifier(n_neighbors=3)

# Entrenamiento
KNN_classifier.fit(xtrain, ytrain)

# Prediccion
y_hat_KNN = KNN_classifier.predict(xtest)
print(y_hat_KNN)

# Precision
acc = np.sum (ytest == y_hat_KNN)/len(ytest)
print('El algoritmo con n=3 tiene una precision del: ' + str(acc))


# Creamos el clasificador para n=4
KNN_classifier = KNeighborsClassifier(n_neighbors=4)

# Entrenamiento
KNN_classifier.fit(xtrain, ytrain)

# Prediccion
y_hat_KNN = KNN_classifier.predict(xtest)
print(y_hat_KNN)

# Precision
acc = np.sum (ytest == y_hat_KNN)/len(ytest)
print('El algoritmo con n=4 tiene una precision del: ' + str(acc))
# Out:
# ['loc2' 'loc3']
# El algoritmo con n=1 tiene una precision del: 1.0
# ['loc2' 'loc1']
# El algoritmo con n=2 tiene una precision del: 0.5
# ['loc1' 'loc1']
# El algoritmo con n=3 tiene una precision del: 0.0
# ['loc1' 'loc1']
# El algoritmo con n=4 tiene una precision del: 0.0
# /home/alumno/.conda/envs/tds_20_21/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/alumno/.conda/envs/tds_20_21/lib/python3.6/site-packages/ipykernel_launcher.py:25: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
